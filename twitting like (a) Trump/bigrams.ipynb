# %%
import os
import csv
import re
from collections import defaultdict, Counter
import nltk
from nltk import bigrams, trigrams
import random

# %%
def remove_punctuation(word):
    return re.sub(r'[^\w\s]', '', word)

# %% [markdown]
# Lettura del trump twitter archive

# %%
file_name = 'tweets.csv'
current_dir = os.getcwd()
file_path = os.path.join(current_dir, 'trump_twitter_archive/', file_name)

with open(file_path, 'r', encoding='utf-8') as train:
   prime_10_righe = train.readlines()[1:]

# %% [raw]
# print('ciao')

# %% [markdown]
# Pulizia dei tweet

# %%
tweets = []
for riga in prime_10_righe:
   riga = riga.split(',')
   riga[1] = re.sub(r"http\S+", "", riga[1])
   tweets.append(riga[1])
print(tweets)
# Out:
# ['LOSER! ', 'Most of the money raised by the RINO losers of the so-called “Lincoln Project” goes into their own pockets. With what I’ve done on Judges Taxes Regulations Healthcare the Military Vets (Choice!) &amp; protecting our great 2A they should love Trump. Problem is I BEAT THEM ALL!', '....because they don’t know how to win and their so-called Lincoln Project is a disgrace to Honest Abe. I don’t know what Kellyanne did to her deranged loser of a husband Moonface but it must have been really bad. John Weaver lost big for Kasich (to me). Crazed Rick Wilson....', '....lost for Evan “McMuffin” McMullin (to me). Steve Schmidt &amp; Reed Galvin lost for John McCain Romney’s campaign manager (?) lost big to “O” &amp; Jennifer Horn got thrown out of the New Hampshire Republican Party. They’re all LOSERS but Abe Lincoln Republican is all smiles!', '....get even for all of their many failures. You see these loser types don’t care about 252 new Federal Judges 2 great Supreme Court Justices a rebuilt military a protected 2nd Amendment biggest EVER Tax &amp; Regulation cuts and much more. I didn’t use any of them....', 'Cryin Chuck Schumer compared to what other Senators have brought home to their states has brought very little back to N.Y. A totally overrated loser the one thing he has given them is SALT. He never even called me to stop it. No wonder Cuomo &amp; most others can’t stand him. AOC!', 'They are Fake News Losers! ', 'The Wall Street Journal Editorial Board doesn’t have a clue on how to fight and win. Their views on Tariffs &amp; Trade are losers for the U.S. but winners for other countries including China. If we followed their standards  we’d have no Country left. They should love Sleepy Joe!', 'Pocahontas working in conjunction with the Democrat Party totally destroyed the campaign of Bernie Sanders. If she would have quit 3 days earlier Sanders would have beaten Biden in a route it wouldn’t even have been close. They also got two other losers to support Sleepy Joe!', 'Elizabeth “Pocahontas” Warren other than Mini Mike was the loser of the night. She didn’t even come close to winning her home state of Massachusetts. Well now she can just sit back with her husband and have a nice cold beer!', 'The biggest loser tonight by far is Mini Mike Bloomberg. His “political” consultants took him for a ride. $700 million washed down the drain and he got nothing for it but the nickname Mini Mike and the complete destruction of his reputation. Way to go Mike!', 'A so-called reporter named @JohnJHarwood who bombed so badly in the 2016 Presidential Debates that I thought he was going to be immediately fired (a Mini Mike type performance) is now with Fake News @CNN. A total loser!', 'To the people of South Carolina Tom Steyer is a joke laughed at by everyone a total incompetent. He made money in coal now he “hates” coal. Did you see him fawning over Crazy Bernie? Has no chance a loser for South Carolina doesn’t deserve your vote!', 'RT @ByronYork: Amusing: First Bloomberg called for Biden Buttigieg Klobuchar to quit race. Hey all you losers leave it to Mike! Now Te…', 'Mini Mike Bloomberg is a LOSER who has money but can’t debate and has zero presence you will see. He reminds me of a tiny version of Jeb “Low Energy” Bush but Jeb has more political skill and has treated the Black community much better than Mini! ', 'Steyer is a major loser. Just doesn’t get it. This is second time with Bernie! ', 'Two stone cold losers from Amazon WP. Almost every story is a made up lie just like corrupt pol Shifty Schiff who fraudulently made up my call with Ukraine. Fiction! ', "RT @RepMattGaetz: There are a lot of moderate Dems who recognize what a political loser impeachment is.They're encouraging their leadersh…", 'Don’t get why @FoxNews puts losers on like @RepSwalwell (who got ZERO as presidential candidate before quitting) Pramila Jayapal David Cicilline and others who are Radical Left Haters? The Dems wouldn’t let @FoxNews get near their bad rat ...

# %% [markdown]
# Creazione dei brigrammi e trigrammi

# %%
# Costruzione dei modelli a bigrammi e trigrammi
model_bigrams = defaultdict(lambda: defaultdict(lambda: 0))
model_trigrams = defaultdict(lambda: defaultdict(lambda: 0))

for tweet in tweets:
    words = tweet.split()
    clean_words = [remove_punctuation(word) for word in words]

        
    # Bigrammi
    for w1, w2 in bigrams(clean_words):
        model_bigrams[w1.lower()][w2.lower()] += 1
    
    # Trigrammi
    for w1, w2, w3 in trigrams(clean_words):
        model_trigrams[(w1.lower(), w2.lower())][w3.lower()] += 1

print(model_bigrams)
# Out:
# defaultdict(<function <lambda> at 0x0000024C0CD5D9D0>, {'most': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B550>, {'of': 1, 'others': 1, 'disloyal': 1, 'important': 1, 'people': 2, 'corrupt': 1, 'slanted': 1, 'thought': 1, 'overrated': 1, 'envied': 1}), 'of': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2BEE0>, {'the': 30, 'a': 4, 'their': 2, 'them': 1, 'bernie': 1, 'massachusetts': 1, 'his': 4, 'south': 1, 'jeb': 1, 'moderate': 1, 'zero': 1, 'relentless': 1, 'michigan': 1, 'everybody': 1, 'control': 1, 'london': 1, 'vicious': 1, 'your': 1, 'campaign': 1, '13': 1, 'trouble': 2, 'big': 1, 'immigration': 1, 'these': 2, 'all': 1, 'scotland': 1, 'defeat': 1, 'philadelphias': 1, 'politics': 2, 'which': 1, 'success': 1, 'haters': 5, 'goldberg': 1, 'losers': 2, 'fate': 6, 'everything': 1, 'ny': 1, 'july': 1, 'this': 1, 'lives': 1, 's': 1, 'yourself': 1, 'blackdog': 1, 'myself': 1, 'time': 2, 'you': 2, 'celebrity': 1, 'successand': 1, '': 1, 'losera': 1, 'forbes': 1, 'millions': 1, 'dollars': 1, 'barackobama': 1, 'touch': 1}), 'the': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B940>, {'money': 2, 'rino': 1, 'socalled': 1, 'military': 1, 'new': 1, 'one': 1, 'wall': 1, 'us': 2, 'democrat': 1, 'campaign': 1, 'loser': 2, 'night': 1, 'biggest': 3, 'drain': 2, 'nickname': 1, 'complete': 1, '2016': 2, 'people': 4, 'black': 1, 'dems': 2, 'presidential': 1, 'polls': 1, 'founders': 1, 'worst': 3, 'witch': 2, 'republican': 3, 'do': 1, 'hell': 3, 'it': 1, 'comcastnbc': 1, 'few': 1, 'haters': 37, 'dumbest': 2, 'party': 1, 'nomination': 1, 'great': 4, 'same': 4, 'corrupt': 1, 'visiting': 1, 'united': 2, 'most': 3, 'crimes': 1, 'other': 2, 'lives': 1, 'job': 1, 'losers': 22, 'will': 1, 'last': 1, 'president': 1, 'fbi': 5, 'act': 1, 'insurance': 1, 'lovely': 2, 'fbis': 1, 'totally': 1, 'fact': 3, 'beginning': 1, 'government': 3, 'fake': 2, 'democrats': 1, 'mainstream': 1, 'interest': 1, 'philippines': 1, 'sights': 1, 'trump': 1, 'winners': 9, 'gop': 1, 'liars': 1, 'pledge': 2, 'reason': 1, 'big': 2, 'two': 1, 'worthless': 1, 'unionleader': 1, 'frontrunner': 1, 'talk': 1, 'mayor': 1, 'media': 1, 'world': 3, 'political': 1, 'debate': 1, 'american': 1, 'conservative': 1, 'best': 3, 'specialreport': 1, 'press': 1, 'preeminent': 1, 'response': 1, 'jimmyfallon': 1, 'oval': 1, 'dying': 1, 'central': 1, 'rest': 2, 'oil': 1, 'guys': 1, 'national': 1, 'truth': 1, 'courthes': 1, 'faux': 1, 'only': 1, 'patch': 1, 'repetitive': 1, 'benefit': 1, 'way': 1, 'sternshow': 1, 'bet': 1, 'finale': 1, 'highest': 1, 'name': 1, 'trolls': 1, 'coolest': 1, 'don': 1, 'apprentice': 1, 'planet': 1, 'wwe': 1, 'mavs': 1, 'playoffs': 1, 'seanhannity': 1, 'losing': 1, 'many': 2, 'hope': 1, 'obama': 1, 'ruling': 1, 'tea': 2, 'brains': 1, 'third': 1, 'small': 1, 'award': 1, 'golf': 1, 'year': 1, 'huffington': 1, 'case': 1, 'thought': 1, 'sp': 1}), 'money': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B790>, {'raised': 1, 'in': 1, 'but': 1, 'from': 1, 'losing': 1, 'off': 1, 'via': 1, 'given': 1}), 'raised': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B4C0>, {'by': 1}), 'by': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2BF70>, {'the': 6, 'far': 2, 'everyone': 1, 'all': 1, 'those': 1, 'comey': 2, 'these': 2, 'almost': 1, 'a': 1, 'many': 1, 'losers': 1, 'winners': 1, 'himself': 1, 'jameshohmann': 1}), 'rino': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B700>, {'losers': 1}), 'losers': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2BD30>, {'of': 3, 'but': 1, 'for': 3, 'to': 2, 'leave': 1, 'from': 1, 'on': 4, 'making': 1, 'not': 1, 'thought': 1, 'and': 14, 'we': 2, 'all': 1, 'who': 3, 'that': 2, 'are': 1, 'in': 1, 'like': 4, 'young': 1, 'proving': 1, 'lets': 1, 'must': 3, 'is': 7, 'alone': 1, 'donaldtrump': 1, 'out': 1, 'with': 2, 'a': 3, 'happy': 1, 'will': 1, 'i': 3, 'vote': 1, 'dont': 2, 'ignored': 1, '8': 1, 'long': 1,  ...

# %% [markdown]
# Calcolo delle probabilità per i bigrammi e i trigrammi

# %%
#calcolo probabilità bigrammi
for w1 in model_bigrams:
  tot = sum(model_bigrams[w1].values())
  for w2 in model_bigrams[w1]:
      model_bigrams[w1][w2] /= tot
print(model_bigrams)
# Out:
# defaultdict(<function <lambda> at 0x0000024C0CD5D9D0>, {'most': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B550>, {'of': 0.09090909090909091, 'others': 0.09090909090909091, 'disloyal': 0.09090909090909091, 'important': 0.09090909090909091, 'people': 0.18181818181818182, 'corrupt': 0.09090909090909091, 'slanted': 0.09090909090909091, 'thought': 0.09090909090909091, 'overrated': 0.09090909090909091, 'envied': 0.09090909090909091}), 'of': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2BEE0>, {'the': 0.2830188679245283, 'a': 0.03773584905660377, 'their': 0.018867924528301886, 'them': 0.009433962264150943, 'bernie': 0.009433962264150943, 'massachusetts': 0.009433962264150943, 'his': 0.03773584905660377, 'south': 0.009433962264150943, 'jeb': 0.009433962264150943, 'moderate': 0.009433962264150943, 'zero': 0.009433962264150943, 'relentless': 0.009433962264150943, 'michigan': 0.009433962264150943, 'everybody': 0.009433962264150943, 'control': 0.009433962264150943, 'london': 0.009433962264150943, 'vicious': 0.009433962264150943, 'your': 0.009433962264150943, 'campaign': 0.009433962264150943, '13': 0.009433962264150943, 'trouble': 0.018867924528301886, 'big': 0.009433962264150943, 'immigration': 0.009433962264150943, 'these': 0.018867924528301886, 'all': 0.009433962264150943, 'scotland': 0.009433962264150943, 'defeat': 0.009433962264150943, 'philadelphias': 0.009433962264150943, 'politics': 0.018867924528301886, 'which': 0.009433962264150943, 'success': 0.009433962264150943, 'haters': 0.04716981132075472, 'goldberg': 0.009433962264150943, 'losers': 0.018867924528301886, 'fate': 0.05660377358490566, 'everything': 0.009433962264150943, 'ny': 0.009433962264150943, 'july': 0.009433962264150943, 'this': 0.009433962264150943, 'lives': 0.009433962264150943, 's': 0.009433962264150943, 'yourself': 0.009433962264150943, 'blackdog': 0.009433962264150943, 'myself': 0.009433962264150943, 'time': 0.018867924528301886, 'you': 0.018867924528301886, 'celebrity': 0.009433962264150943, 'successand': 0.009433962264150943, '': 0.009433962264150943, 'losera': 0.009433962264150943, 'forbes': 0.009433962264150943, 'millions': 0.009433962264150943, 'dollars': 0.009433962264150943, 'barackobama': 0.009433962264150943, 'touch': 0.009433962264150943}), 'the': defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CF2B940>, {'money': 0.008097165991902834, 'rino': 0.004048582995951417, 'socalled': 0.004048582995951417, 'military': 0.004048582995951417, 'new': 0.004048582995951417, 'one': 0.004048582995951417, 'wall': 0.004048582995951417, 'us': 0.008097165991902834, 'democrat': 0.004048582995951417, 'campaign': 0.004048582995951417, 'loser': 0.008097165991902834, 'night': 0.004048582995951417, 'biggest': 0.012145748987854251, 'drain': 0.008097165991902834, 'nickname': 0.004048582995951417, 'complete': 0.004048582995951417, '2016': 0.008097165991902834, 'people': 0.016194331983805668, 'black': 0.004048582995951417, 'dems': 0.008097165991902834, 'presidential': 0.004048582995951417, 'polls': 0.004048582995951417, 'founders': 0.004048582995951417, 'worst': 0.012145748987854251, 'witch': 0.008097165991902834, 'republican': 0.012145748987854251, 'do': 0.004048582995951417, 'hell': 0.012145748987854251, 'it': 0.004048582995951417, 'comcastnbc': 0.004048582995951417, 'few': 0.004048582995951417, 'haters': 0.14979757085020243, 'dumbest': 0.008097165991902834, 'party': 0.004048582995951417, 'nomination': 0.004048582995951417, 'great': 0.016194331983805668, 'same': 0.016194331983805668, 'corrupt': 0.004048582995951417, 'visiting': 0.004048582995951417, 'united': 0.008097165991902834, 'most': 0.012145748987854251, 'crimes': 0.004048582995951417, 'other': 0.008097165991902834, 'lives': 0.004048582995951417, 'job': 0.004048582995951417, 'losers': 0.08906882591093117, 'will': 0.004048582995951417, 'last': 0.004048582995951417, 'president': 0.004048582995951417, 'fbi': 0.020242914979757085, 'act': 0.004048582995951417, 'insurance':  ...

# %%
#calcolo probabilità trigrammi
for w1w2 in model_trigrams:
    tot = sum(model_trigrams[w1w2].values())
    for w3 in model_trigrams[w1w2]:
        model_trigrams[w1w2][w3] /= tot
print(model_trigrams)
# Out:
# defaultdict(<function <lambda> at 0x0000024C0CCA4A60>, {('most', 'of'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0D5F7EE0>, {'the': 1.0}), ('of', 'the'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0D5F7AF0>, {'money': 0.03333333333333333, 'socalled': 0.03333333333333333, 'new': 0.03333333333333333, 'night': 0.03333333333333333, 'dumbest': 0.03333333333333333, 'united': 0.06666666666666667, 'people': 0.03333333333333333, 'president': 0.03333333333333333, 'losers': 0.06666666666666667, 'witch': 0.03333333333333333, 'great': 0.06666666666666667, 'fbi': 0.06666666666666667, 'mainstream': 0.03333333333333333, 'political': 0.03333333333333333, 'conservative': 0.03333333333333333, 'haters': 0.16666666666666666, 'world': 0.06666666666666667, 'repetitive': 0.03333333333333333, 'highest': 0.03333333333333333, 'obama': 0.03333333333333333, 'year': 0.03333333333333333}), ('the', 'money'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0D5F7D30>, {'raised': 0.5, 'losing': 0.5}), ('money', 'raised'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0D5B9310>, {'by': 1.0}), ('raised', 'by'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0C6989D0>, {'the': 1.0}), ('by', 'the'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0C773DC0>, {'rino': 0.16666666666666666, 'other': 0.16666666666666666, 'fbi': 0.16666666666666666, 'courthes': 0.16666666666666666, 'people': 0.16666666666666666, 'way': 0.16666666666666666}), ('the', 'rino'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0A846C10>, {'losers': 1.0}), ('rino', 'losers'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0A8469D0>, {'of': 1.0}), ('losers', 'of'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C5E0>, {'the': 0.6666666666666666, 'which': 0.3333333333333333}), ('the', 'socalled'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C550>, {'lincoln': 1.0}), ('socalled', 'lincoln'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C4C0>, {'project': 1.0}), ('lincoln', 'project'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C430>, {'goes': 0.5, 'is': 0.5}), ('project', 'goes'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C3A0>, {'into': 1.0}), ('goes', 'into'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C310>, {'their': 1.0}), ('into', 'their'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C280>, {'own': 1.0}), ('their', 'own'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C1F0>, {'pockets': 0.3333333333333333, 'then': 0.3333333333333333, 'peril': 0.3333333333333333}), ('own', 'pockets'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C160>, {'with': 1.0}), ('pockets', 'with'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C0D0>, {'what': 1.0}), ('with', 'what'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C040>, {'ive': 1.0}), ('what', 'ive'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4CDC0>, {'done': 1.0}), ('ive', 'done'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C820>, {'on': 1.0}), ('done', 'on'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C700>, {'judges': 1.0}), ('on', 'judges'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4CEE0>, {'taxes': 1.0}), ('judges', 'taxes'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4CA60>, {'regulations': 1.0}), ('taxes', 'regulations'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4CB80>, {'healthcare': 1.0}), ('regulations', 'healthcare'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4CF70>, {'the': 1.0}), ('healthcare', 'the'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x0000024C0CB4C8B0>, {'military': 1.0}), ('the', 'military'): defaultdic ...

# %% [markdown]
# GENERAZIONE DI TWEET BASATI SU BIGRAMMI

# %%
#questo blocco sceglie una parola randomica tra quelle presenti nei tweet,
#dopodichè produce una frase di 13 parole basandosi sulle probabilità ottenute con i bigrammi

max_lenght = 12

for frase in range(5):   
    first_words = list(model_bigrams.keys())
    start_word = random.choice(first_words)
    bi_tweet = [start_word]
    current_word = start_word
    print(start_word)
    
    for i in range(max_lenght):
        max_prob = max(model_bigrams[current_word].values())
        #new_word = model_bigrams[current_word][max_prob]
        bi_tweet.append(new_word)
        current_word = new_word
    print(bi_tweet)
# Out:
# realizes

# %% [markdown]
# GENERAZIONE DI TWEET BASATI SU TRIGRAMMI

# %%
#questo blocco sceglie una parola randomica tra quelle presenti nei tweet,
#dopodichè produce una frase di 13 parole basandosi sulle probabilità ottenute con i trigrammi

max_lenght = 12

for frase in range(5):   
    first_words = list(model_bigrams.keys())
    start_word = random.choice(first_words)
    tri_tweet = [start_word]
    print(start_word)
    
    for i in range(max_lenght):
        
        tri_tweet.append("c")
    print(tri_tweet)
